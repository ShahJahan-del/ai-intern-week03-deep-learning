# %%
import sys
# !{sys.executable} -m pip install transformers datasets tokenizers

from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 25.2 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 get_ipython().system('pip install transformers datasets tokenizers')
# ----> 3 from transformers import pipeline
#       5 classifier = pipeline("sentiment-analysis")
#       6 classifier("I've been waiting for a HuggingFace course my whole life.")
#
# ModuleNotFoundError: No module named 'transformers'
